# %%
import pandas as pd
import json
import requests
from datetime import date, time, datetime, timedelta
import numpy as np
import sklearn
import plotly.express as p

# %% [markdown]
# ### Associated Press Media API
#
# Learned that this doesn't work! We'd need to pay for access to an API key and there's simply some things that aren't worth it.

# %%
url = "https://api.ap.org/media/v/content/search?q=Schindler's+List"

api_key = "api_key"  # this would be the thing we'd need to pay for

headers = {
    "x-api-key": api_key
}

url_text = requests.get(url, headers=headers).text    
url_text
# Out:
# '{ "api_version": "v", "api_mode": "", "id": "cd365c55-7b4c-4f16-960a-397fb206fb90", "method": "/content/search.GET" , "error":{"status":401, "code":2000, "message":"Supply a valid apikey" , "timestamp":"2024-05-26T08:47:30.631Z" } }'

# %% [markdown]
# ### World News API

# %%
pip install worldnewsapi
# Out:
# Requirement already satisfied: worldnewsapi in /Users/sydneyschulz/opt/anaconda3/lib/python3.9/site-packages (1.0.11)
# Requirement already satisfied: typing-extensions>=4.7.1 in /Users/sydneyschulz/opt/anaconda3/lib/python3.9/site-packages (from worldnewsapi) (4.12.0)
# Requirement already satisfied: pydantic>=2 in /Users/sydneyschulz/opt/anaconda3/lib/python3.9/site-packages (from worldnewsapi) (2.7.2)
# Requirement already satisfied: urllib3<2.1.0,>=1.25.3 in /Users/sydneyschulz/opt/anaconda3/lib/python3.9/site-packages (from worldnewsapi) (1.26.11)
# Requirement already satisfied: python-dateutil in /Users/sydneyschulz/opt/anaconda3/lib/python3.9/site-packages (from worldnewsapi) (2.8.2)
# Requirement already satisfied: pydantic-core==2.18.3 in /Users/sydneyschulz/opt/anaconda3/lib/python3.9/site-packages (from pydantic>=2->worldnewsapi) (2.18.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/sydneyschulz/opt/anaconda3/lib/python3.9/site-packages (from pydantic>=2->worldnewsapi) (0.7.0)
# Requirement already satisfied: six>=1.5 in /Users/sydneyschulz/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil->worldnewsapi) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import worldnewsapi as wn
from worldnewsapi.rest import ApiException

api_key = 'd4e50c1f711f4abbb8c8a5b5381ec0df'
config = wn.Configuration(api_key={'apiKey': api_key})

try:
    instance = wn.NewsApi(wn.ApiClient(config))
    response = instance.search_news(
        text='Russia', 
        earliest_publish_date='2000-01-01', 
        latest_publish_date='2024-05-26')
except ApiException as e:
    print("Exception when calling NewsApi:", e)
    
for article in response:
    print(article)
# Out:
# ('offset', 0)
# ('number', 10)
# ('available', 525757)
# ('news', [NewsArticle(id=49692380, title='Zelensky claims significant gains in northeastern Ukraine as key city retaken', text='In a nightly address Thursday, Zelensky claimed the country\'s military had retaken more than 1,000 square kilometers of territory since the beginning of the month. Oleksii Hromov, the deputy head of the main operations directorate of the General Staff of the Armed Forces of Ukraine, said Ukrainian forces were able to advance 50 kilometers (about 31 miles) in the Kharkiv region and liberate "more than 20 settlements." Through geolocation and the statements of the Ukrainian military, independent analysts and Russian military bloggers, it\'s estimated that Ukrainian forces have taken well over 400 square kilometers of territory this week in the Kharkiv region. Meanwhile, some Russian troops in the Kharkiv region have deserted and abandoned their uniforms due to Russia\'s "significant losses," the General Staff of the Ukrainian Armed Forces said, adding that the soldiers are hoping to blend in while wearing civilian clothing. "Personnel of the occupying forces in civilian clothes resort to desertion and try to return to the territory of the Russian Federation," the General Staff said in a situational update Friday, claiming that 15 such cases had been observed. The Intelligence Directorate of the Ukrainian Defense Ministry said that the Russian 202nd Motorized Rifle Regiment, "located in the Kharkiv region, withdrew from their positions and moved to the nearest forest. The unit was left without commanders and communications." The Directorate claimed that Russian soldiers were "calling to relatives with requests to contact the command and find out where they should go next. Some of them ask their wives to contact the hotlines of the Ministry of Defense of Russia and the Red Cross with the demand to remove them from the territory of Ukraine." It provided no evidence for the assertion. Counteroffensives on two fronts While the southern front, in Kherson region, looks set to be one of the main theaters of conflict as the war heads towards winter, a new Ukrainian push in Kharkiv could stretch Russian forces across two disparate locations. In recent weeks, Russia redeployed some forces to the south to bolster its ranks ahead of the Ukrainian counteroffensive in Kherson region, according to Ukrainian officials and footage of equipment moving through Crimea geolocated by CNN. Photos: Russia invades UkraineRafael Mariano Grossi, Director General of the International Atomic Energy Agency, speaks to the press at his hotel before leaving to inspect the Zaporizhzhia nuclear power plant in Zaporizhzhia, Ukraine, on September 1.Hide Caption 1 of 252 Photos: Russia invades UkraineGraves of fallen soldiers in Lychakiv Cemetery, Lviv, as Ukrainians celebrate Independence Day, and mark the six month anniversary of the Russian invasion, on August 24. Hide Caption 2 of 252 Photos: Russia invades UkraineRockets launched from the Belgorod region in Russia are seen at dawn in Kharkiv, Ukraine, on August 15.Hide Caption 3 of 252 Photos: Russia invades UkraineValentyna Kondratieva, 75, left, is comforted by a neighbor as they stand outside her damaged home, in Kramatorsk, Ukraine, on August 13, after a rocket attack.Hide Caption 4 of 252 Photos: Russia invades UkraineThe bulk carrier NAVI STAR, transporting a cargo of corn, is seen leaving port of Odesa, Ukraine, on August 5. Hide Caption 5 of 252 Photos: Russia invades UkraineA young girl holds her dog as an evacuation train departs from Pokrovsk, eastern Ukraine, on August 2.Hide Caption 6 of 252 Photos: Russia invades UkraineUkrainian State Emergency Service firefighters attend to a fire at an oil depot in Mykolaiv, Ukraine, on August 2.Hide Caption 7 of 252 Photos: Russia invades UkraineA firefighter extinguishes a burning hospital building hit by a Russian missile strike in Mykolaiv, Ukraine, on August 1.Hide Caption 8 of 252 Photos: Russia invades UkraineRussian tanks near  ...

# %% [markdown]
# ### World News API: Search Version
# - Url: https://api.worldnewsapi.com/search-news
# - API Key: d4e50c1f711f4abbb8c8a5b5381ec0df
# - Params: text=`'search term'`, language=`'en'` or `'ru'`

# %%
def search_api(query, api_key, min_date, max_date):
    """
    Description: Grabs intial request from a scrape of the World News Search API.
    
    Args: 
        query(string): args for search term, typically in phrase form
        api_key(string): api key for query
        min_date(string): news must be published after this date 'YYYY-MM-DD'
        max_date(string: news must be published before this date 'YYYY-MM-DD'
        
    Returns:
        df(DataFrame): of 
    """
    df = pd.DataFrame()
    
    headers = {'x-api-key': api_key}
    
    url = f'https://api.worldnewsapi.com/search-news?&text={query}&number=10&earliest-publish-date={min_date}&latest-publish-date={max_date}'
    
    response = requests.get(url, headers=headers).json() # keys = 'offset', 'number', 'available', 'news'
    news = response['news'] # array of dicts
    
    # can also add more to this as we need, but this is the basic stuff as of now
    data = {
        'date': [], 
        'sentiment': [], 
        'text': [], 
        'source_country': [],
        'queried_country': [], 
        'url': [],
#         'summary': []
    }
    
    for item in response.get('news', []):
        if (item.get('sentiment', None) != None) & (item.get('source_country', None) != None):
            data['queried_country'].append(query)
            data['date'].append(item.get('publish_date', None))
            data['sentiment'].append(item.get('sentiment'))
            data['source_country'].append(item.get('source_country'))
            data['text'].append(item.get('text', None))   
            data['url'].append(item.get('url', None))
#             date['summary'].append(item.get('summary', None))
        
    return pd.DataFrame.from_dict(data)

# %% [markdown]
# Testing the above funciton and seeing what it outputs below using a day in 2022 with the target query of "Russia".

# %%
api_key = 'd4e50c1f711f4abbb8c8a5b5381ec0df'
query = 'Ukraine'
min_date = '2022-11-11'
max_date = '2022-11-12'
response = search_api(query, api_key, min_date, max_date)

# %%
response.head()
# Out:
#                   date  sentiment  \
# 0  2022-11-11 12:00:00     -1.000
# 1  2022-11-11 12:00:01      0.187
# 2  2022-11-11 12:00:02     -0.159
# 3  2022-11-11 12:00:28     -0.318
# 4  2022-11-11 12:00:48      0.219
#
#                                                 text source_country  \
# 0  Das könnte Sie auch interessieren Emouvant réc...             lu
# 1  The author will give a version of this talk vi...             us
# 2  Mum of one Rachel Roberts, 50, said: "I'm shoc...             GB
# 3  JERUSALEM — Rania Elias, a Palestinian mother ...             us
# 4  Article content Ukrainians have shown bravery ...             ca
#
#   queried_country                                                url
# 0         Ukraine  https://www.wort.lu/de/kultur/anschauen-bewund...
# 1         Ukraine  https://www.salon.com/2022/11/11/americas-addi...
# 2         Ukraine  https://www.express.co.uk/news/uk/1695241/ange...
# 3         Ukraine  https://www.washingtonpost.com/world/2022/11/1...
# 4         Ukraine  https://windsorstar.com/opinion/letters/reader...

# %% [markdown]
# Formatting and grabbing more of the data (getting a lot of data over a long period of time).

# %%
def df_data_over_time(query, api_key):
    """
    Description: Grabs information about different countries for one day each month for provided date range.
    
    Args:
        query(array): names of countries to be queried, ideally in full name
        api_key(str): api key
        
    Returns:
        df(DataFrame): extended dataframe containing information about each provided country over past 5 years
    """
    date_str = '%Y-%m-%d'
    end = datetime.today()
    start = end -  timedelta(days=5*365)
    mid = start + timedelta(days=30)
    
    df = pd.DataFrame()
        
    while mid < end:
        for country in query:
            results = search_api(country, api_key, datetime.strftime(start, date_str), datetime.strftime(mid, date_str))
            df = pd.concat([df, results])
            start += timedelta(days=30)
            mid += timedelta(days=30)
            
    return df

# %%
query2 = ['Ukraine']
results2 = df_data_over_time(query2, '0597f4c47fbb467abea860f1ae94d6fd')
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385         try:
# --> 386             self._validate_conn(conn)
#     387         except (SocketTimeout, BaseSSLError) as e:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#    1041         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042             conn.connect()
#    1043
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connection.py in connect(self)
#     413
# --> 414         self.sock = ssl_wrap_socket(
#     415             sock=conn,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     448     if send_sni:
# --> 449         ssl_sock = _ssl_wrap_socket_impl(
#     450             sock, context, tls_in_tls, server_hostname=server_hostname
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/util/ssl_.py in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     492     if server_hostname:
# --> 493         return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494     else:
#
# ~/opt/anaconda3/lib/python3.9/ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     500         # ctx._wrap_socket()
# --> 501         return self.sslsocket_class._create(
#     502             sock=sock,
#
# ~/opt/anaconda3/lib/python3.9/ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1040                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1041                     self.do_handshake()
#    1042             except (OSError, ValueError):
#
# ~/opt/anaconda3/lib/python3.9/ssl.py in do_handshake(self, block)
#    1309                 self.settimeout(None)
# -> 1310             self._sslobj.do_handshake()
#    1311         finally:
#
# ConnectionResetError: [Errno 54] Connection reset by peer
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     488             if not chunked:
# --> 489                 resp = conn.urlopen(
#     490                     method=request.method,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     786
# --> 787             retries = retries.increment(
#     788                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     549             if read is False or not self._is_method_retryable(method):
# --> 550                 raise six.reraise(type(error), error, _stacktrace)
#     551             elif read is not None:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/packages/six.py in reraise(tp, value, tb)
#     768             if value.__traceback__ is not tb:
# --> 769                 raise value.with_traceback(tb)
#     770             raise value
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385         try:
# --> 386             self._validate_conn(conn)
#     387         except (SocketTimeout, BaseSSLError) as e:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#    1041         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042             conn.connect()
#    1043
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connection.py in connect(self)
#     413
# --> 414         self.sock = ssl_wrap_socket(
#     415             sock=conn,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     448     if send_sni:
# --> 449         ssl_sock = _ssl_wrap_socket_impl(
#     450             sock, context, tls_in_tls, server_hostname=server_hostname
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/util/ssl_.py in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     492     if server_hostname:
# --> 493         return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494     else:
#
# ~/opt/anaconda3/lib/python3.9/ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     500         # ctx._wrap_socket()
# --> 501         return self.sslsocket_class._create(
#     502             sock=sock,
#
# ~/opt/anaconda3/lib/python3.9/ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1040                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1041                     self.do_handshake()
#    1042             except (OSError, ValueError):
#
# ~/opt/anaconda3/lib/python3.9/ssl.py in do_handshake(self, block)
#    1309                 self.settimeout(None)
# -> 1310             self._sslobj.do_handshake()
#    1311         finally:
#
# ProtocolError: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# /var/folders/qp/xtx2ytg15kx84mfvhl5v29h80000gn/T/ipykernel_4953/1656574862.py in <module>
#       1 query2 = ['Ukraine']
# ----> 2 results2 = df_data_over_time(query2, '0597f4c47fbb467abea860f1ae94d6fd')
#
# /var/folders/qp/xtx2ytg15kx84mfvhl5v29h80000gn/T/ipykernel_4953/180891347.py in df_data_over_time(query, api_key)
#      19     while mid < end:
#      20         for country in query:
# ---> 21             results = search_api(country, api_key, datetime.strftime(start, date_str), datetime.strftime(mid, date_str))
#      22             df = pd.concat([df, results])
#      23             start += timedelta(days=30)
#
# /var/folders/qp/xtx2ytg15kx84mfvhl5v29h80000gn/T/ipykernel_4953/2773156459.py in search_api(query, api_key, min_date, max_date)
#      18     url = f'https://api.worldnewsapi.com/search-news?&text={query}&number=10&earliest-publish-date={min_date}&latest-publish-date={max_date}'
#      19
# ---> 20     response = requests.get(url, headers=headers).json() # keys = 'offset', 'number', 'available', 'news'
#      21     news = response['news'] # array of dicts
#      22
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     585         }
#     586         send_kwargs.update(settings)
# --> 587         resp = self.send(prep, **send_kwargs)
#     588
#     589         return resp
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     699
#     700         # Send the request
# --> 701         r = adapter.send(request, **kwargs)
#     702
#     703         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     545
#     546         except (ProtocolError, OSError) as err:
# --> 547             raise ConnectionError(err, request=request)
#     548
#     549         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))

# %% [markdown]
# Quick save of the phase 2 data scraping from the World News API.

# %%
results.to_csv('Worldwide News.csv')
results.head()
# Out:
#                   date  sentiment  \
# 0  2019-06-12 18:48:59     -0.308
# 0  2019-07-12 17:14:00     -0.108
# 0  2019-10-23 15:32:04      0.292
# 1  2019-10-23 15:34:13      0.398
# 2  2019-10-23 15:37:39      0.146
#
#                                                 text source_country  \
# 0  It’s time we start talking about climate chang...             mx
# 0  Even now, as more frequent "king tides" bubble...             us
# 0  The second meeting of the Board of senior memb...             uz
# 1  The Shanghai Cooperation Organization establis...             uz
# 2  All participants of the exhibition “Tea and Co...             uz
#
#   queried_country                                                url  \
# 0          Russia  https://www.amnesty.org/en/latest/news/2019/06...
# 0           China  https://edition.cnn.com/2019/07/11/us/miami-li...
# 0          Russia  http://www.uzreport.com/sco-interbank-associat...
# 1          Russia  http://www.uzreport.com/entrepreneur-committee...
# 2          Russia  http://www.uzreport.com/over-7000-people-visit...
#
#    safety_index  Safety Index        Country
# 0         0.535         0.535  United States
# 0         0.535         0.535  United States
# 0         0.535         0.535  United States
# 1         0.535         0.535  United States
# 2         0.535         0.535  United States

# %%
test = results.iloc[:,:6].reset_index().iloc[:,1:]

# %%
# df_original = data obtained by the api
# df_lookup = data with codes and country codes
lookup_data = {
'Country': ['United States', 'Russia', 'Belgium', 'China'],
'Safety Index': [0.535, 0.585, 0.7, 0.784286],
'country code': ['us', 'ru', 'be', 'cn']
}

df_lookup = pd.DataFrame(lookup_data)
df_lookup
# Out:
#          Country  Safety Index country code
# 0  United States      0.535000           us
# 1         Russia      0.585000           ru
# 2        Belgium      0.700000           be
# 3          China      0.784286           cn

# %%
for index_results, row_results in test.iterrows():
    print(index_results)
    print(row_results)
    country = row_results['queried_country']
    
    for index_look, row_look in df_lookup.iterrows():
        country_code_look = row_look['Country']
        
        if country == country_code_look:
            test.loc[index_results, 'Safety Index'] = row_look['Safety Index']
# Out:
# 0
# date                                             2019-06-12 18:48:59
# sentiment                                                     -0.308
# text               It’s time we start talking about climate chang...
# source_country                                                    mx
# queried_country                                               Russia
# url                https://www.amnesty.org/en/latest/news/2019/06...
# Name: 0, dtype: object
# 1
# date                                             2019-07-12 17:14:00
# sentiment                                                     -0.108
# text               Even now, as more frequent "king tides" bubble...
# source_country                                                    us
# queried_country                                                China
# url                https://edition.cnn.com/2019/07/11/us/miami-li...
# Name: 1, dtype: object
# 2
# date                                             2019-10-23 15:32:04
# sentiment                                                      0.292
# text               The second meeting of the Board of senior memb...
# source_country                                                    uz
# queried_country                                               Russia
# url                http://www.uzreport.com/sco-interbank-associat...
# Name: 2, dtype: object
# 3
# date                                             2019-10-23 15:34:13
# sentiment                                                      0.398
# text               The Shanghai Cooperation Organization establis...
# source_country                                                    uz
# queried_country                                               Russia
# url                http://www.uzreport.com/entrepreneur-committee...
# Name: 3, dtype: object
# 4
# date                                             2019-10-23 15:37:39
# sentiment                                                      0.146
# text               All participants of the exhibition “Tea and Co...
# source_country                                                    uz
# queried_country                                               Russia
# url                http://www.uzreport.com/over-7000-people-visit...
# Name: 4, dtype: object
# 5
# date                                             2019-10-25 13:49:26
# sentiment                                                      0.101
# text               International security experts often draw up l...
# source_country                                                    es
# queried_country                                               Russia
# url                https://english.elpais.com/elpais/2019/10/25/i...
# Name: 5, dtype: object
# 6
# date                                             2019-10-30 05:13:23
# sentiment                                                     -0.542
# text               Bottom line: The current wave of US and Hong K...
# source_country                                                    cn
# queried_country                                                China
# url                http://www.youngchinabiz.com/en/offshore-china...
# Name: 6, dtype: object
# 7
# date                                             2019-11-05 17:28:02
# sentiment                                                     -0.394
# text               Ethiopia saw an 11 point improvement in its in...
# source_country                                                    et
# queried_country                                                China
# url                            http://cyberethiopia.com/2013/?p=2153
# Name: 7, dtype: object
# 8
# date                                             2019-11-06 06:04:21
# sentiment                                                     -0.312
# text               Bottom line: WeChat’s growing hubris, reflecte...
# source_country                                                    cn
# queried_country                                                China
# url                http://www.youngchinabiz.com/en/wechats-hubris...
# Name: 8, dtype: object
# 9
# date                                             2019-11-15 15:39:28
# sentiment                                                      0.061
# text               While Gerard Piqué was helping Spain win the 2...
# source_country                                                    es
# queried_country                                                China
# url                https://elpais.com/elpais/2019/11/13/inenglish...
# Name: 9, dtype: object
# 10
# date                                             2019-11-21 11:08:18
# sentiment                                                     -0.037
# text               Bottom line: Weibo and its stock could remain ...
# source_country                                                    cn
# queried_country                                                China
# url                         http://www.youngchinabiz.com/en/30349-2/
# Name: 10, dtype: object
# 11
# date                                             2019-12-10 10:59:18
# sentiment                                                     -0.144
# text               Here are a few of last week’s headlines: “Swed...
# source_country                                                    es
# queried_country                                              Belgium
# url                https://elpais.com/elpais/2019/12/10/inenglish...
# Name: 11, dtype: object
# 12
# date                                             2019-12-28 10:26:03
# sentiment                                                     -0.144
# text               Human-driven pressures on island-reef systems ...
# source_country                                                    mv
# queried_country                                        United States
# url                https://maldivesindependent.com/environment/in...
# Name: 12, dtype: object
# 13
# date                                             2020-01-02 09:55:40
# sentiment                                                       0.03
# text               Originally published at AlMariam.com WISHING A...
# source_country                                                    et
# queried_country                                        United States
# url                            http://cyberethiopia.com/2013/?p=2161
# Name: 13, dtype: object
# 14
# date                                             2020-01-12 16:07:50
# sentiment                                                      0.142
# text               Over the course of nearly five decades, Sultan...
# source_country                                                    us
# queried_country                                        United States
# url                https://www.theguardian.com/world/2020/jan/12/...
# Name: 14, dtype: object
# 15
# date                                             2020-01-14 11:05:55
# sentiment                                                     -0.005
# text               New Delhi: Several high profile delegates from...
# source_country                                                    in
# queried_country                                        United States
# url                https://transasianews.com/open-article/2020/so...
# Name: 15, dtype: object
# 16
# date                                             2020-01-14 12:45:48
# sentiment                                                     -0.352
# text               Each year, about half-a-million people are mur...
# source_country                                                    es
# queried_country                                        United States
# url                https://elpais.com/elpais/2020/01/14/inenglish...
# Name: 16, dtype: object
# 17
# date                                             2020-01-16 07:48:09
# sentiment                                                      0.031
# text               Raquel Frohlinger, a 26-year-old from New York...
# source_country                                                    es
# queried_country                                        United States
# url                https://elpais.com/elpais/2020/01/14/inenglish...
# Name: 17, dtype: object
# 18
# date                                             2020-01-17 07:47:07
# sentiment                                                     -0.039
# text               Even as this year’s Academy Award nominations ...
# source_country                                                    es
# queried_country                                        United States
# url                https://elpais.com/elpais/2020/01/16/inenglish...
# Name: 18, dtype: object
# 19
# date                                             2020-01-23 12:59:01
# sentiment                                                      0.169
# text               Being a superpower is not what it used to be. ...
# source_country                                                    es
# queried_country                                        United States
# url                https://english.elpais.com/elpais/2020/01/22/i...
# Name: 19, dtype: object
# 20
# date                                             2020-01-24 07:47:05
# sentiment                                                      -0.12
# text               The United States government’s decision to imp...
# source_country                                                    es
# queried_country                                        United States
# url                https://elpais.com/elpais/2020/01/23/inenglish...
# Name: 20, dtype: object
# 21
# date                                             2020-02-27 13:03:50
# sentiment                                                      0.066
# text               Saudi Arabia has taken the unprecedented step ...
# source_country                                                    us
# queried_country                                                China
# url                https://www.theguardian.com/world/2020/feb/27/...
# Name: 21, dtype: object
# 22
# date                                             2020-02-28 01:03:58
# sentiment                                                      0.338
# text               In China the vast majority of deaths from Coro...
# source_country                                                    GB
# queried_country                                                China
# url                https://www.bbc.co.uk/news/av/world-asia-china...
# Name: 22, dtype: object
# 23
# date                                             2020-02-29 19:41:19
# sentiment                                                     -0.279
# text               Satellite images have shown a dramatic decline...
# source_country                                                    GB
# queried_country                                                China
# url                https://www.bbc.co.uk/news/world-asia-51691967...
# Name: 23, dtype: object
# 24
# date                                             2020-03-04 09:02:29
# sentiment                                                     -0.222
# text               China's most popular messaging app has been ce...
# source_country                                                    GB
# queried_country                                                China
# url                https://www.bbc.co.uk/news/world-asia-china-51...
# Name: 24, dtype: object
# 25
# date                                             2020-03-09 01:39:18
# sentiment                                                      0.005
# text               In our series of letters from African writers,...
# source_country                                                    GB
# queried_country                                                China
# url                https://www.bbc.co.uk/news/world-africa-517708...
# Name: 25, dtype: object
# 26
# date                                             2020-03-13 01:18:00
# sentiment                                                      0.145
# text               Two local filmmakers have been recording life ...
# source_country                                                    GB
# queried_country                                                China
# url                https://www.bbc.co.uk/news/av/world-asia-china...
# Name: 26, dtype: object
# 27
# date                                             2020-03-13 03:23:40
# sentiment                                                     -0.429
# text               Mount Everest has shut down for the rest of th...
# source_country                                                    GB
# queried_country                                                China
# url                https://www.bbc.co.uk/news/world-asia-51866342...
# Name: 27, dtype: object
# 28
# date                                             2020-03-16 07:49:06
# sentiment                                                     -0.431
# text               Alibaba co-founder Jack Ma has sent the first ...
# source_country                                                    GB
# queried_country                                                China
# url                https://www.bbc.co.uk/news/business-51904379?a...
# Name: 28, dtype: object
# 29
# date                                             2020-03-16 14:19:19
# sentiment                                                     -0.098
# text               BBC Homepage Skip to content Accessibility Hel...
# source_country                                                    GB
# queried_country                                                China
# url                https://www.bbc.co.uk/news/av/world-asia-china...
# Name: 29, dtype: object
# 30
# date                                             2020-03-17 05:31:43
# sentiment                                                     -0.696
# text               Hong Kong will quarantine all people arriving ...
# source_country                                                    GB
# queried_country                                                China
# url                https://www.bbc.co.uk/news/world-asia-china-51...
# Name: 30, dtype: object
# 31
# date                                             2020-07-09 12:22:17
# sentiment                                                     -0.001
# text               It’s been five years since China began its ass...
# source_country                                                    mx
# queried_country                                                China
# url                https://www.amnesty.org/en/latest/campaigns/20...
# Name: 31, dtype: object
# 32
# date                                             2020-07-17 21:09:55
# sentiment                                                     -0.169
# text               On 30 June, China’s top legislature unanimousl...
# source_country                                                    mx
# queried_country                                                China
# url                https://www.amnesty.org/en/latest/news/2020/07...
# Name: 32, dtype: object
# 33
# date                                             2020-07-22 11:00:00
# sentiment                                                      0.338
# text               Guiding Opinions on Implementing the Cybersecu...
# source_country                                                    cn
# queried_country                                                China
# url                https://chinacopyrightandmedia.wordpress.com/2...
# Name: 33, dtype: object
# 34
# date                                             2020-07-27 09:30:47
# sentiment                                                      0.039
# text               Dapaong is a buzzing, multi-religious city, 13...
# source_country                                                    us
# queried_country                                              Belgium
# url                https://www.theguardian.com/global-development...
# Name: 34, dtype: object
# 35
# date                                             2020-09-02 14:30:48
# sentiment                                                     -0.004
# text               MUNICH — (MunichNOW News) Americans in the Uni...
# source_country                                                    de
# queried_country                                        United States
# url                https://munichnow.com/overseas-american-here-i...
# Name: 35, dtype: object
# 36
# date                                             2020-10-14 11:02:00
# sentiment                                                     -0.244
# text               The decades-long Nagorno-Karabakh conflict bet...
# source_country                                                    pk
# queried_country                                               Russia
# url                https://theviewes.blogspot.com/2020/10/azerbai...
# Name: 36, dtype: object
# 37
# date                                             2020-10-21 12:36:28
# sentiment                                                      0.707
# text               The Himalayas are the highest mountains on Ear...
# source_country                                                    us
# queried_country                                                China
# url                https://www.theguardian.com/books/2020/oct/21/...
# Name: 37, dtype: object
# 38
# date                                             2020-11-11 20:00:47
# sentiment                                                     -0.239
# text               The Dalai Lama has appealed to world leaders t...
# source_country                                                    us
# queried_country                                                China
# url                https://www.theguardian.com/world/2020/nov/11/...
# Name: 38, dtype: object
# 39
# date                                             2020-12-29 13:36:24
# sentiment                                                      0.532
# text               ‘Vaccine for all. 20 points for a fairer and h...
# source_country                                                    it
# queried_country                                        United States
# url                https://zenit.org/2020/12/29/just-in-vatican-l...
# Name: 39, dtype: object
# 40
# date                                             2021-01-04 22:30:42
# sentiment                                                      0.129
# text               Saudi Arabia will reopen its land and sea bord...
# source_country                                                    us
# queried_country                                        United States
# url                https://www.theguardian.com/world/2021/jan/04/...
# Name: 40, dtype: object
# 41
# date                                             2021-01-06 00:00:00
# sentiment                                                      0.435
# text               2ND LEAD (Correction) Indian Minister of Exter...
# source_country                                                    lk
# queried_country                                        United States
# url                https://www.tamilnet.com/art.html?catid=13&art...
# Name: 41, dtype: object
# 42
# date                                             2021-01-07 00:00:00
# sentiment                                                     -0.124
# text               3RD LEAD Boyle prefers IIIM demand over ICC-re...
# source_country                                                    lk
# queried_country                                        United States
# url                https://www.tamilnet.com/art.html?catid=79&art...
# Name: 42, dtype: object
# 43
# date                                             2021-01-08 00:00:00
# sentiment                                                     -0.015
# text               Colombo destroys Mu'l'livaaykkaal memorial mon...
# source_country                                                    lk
# queried_country                                        United States
# url                https://www.tamilnet.com/art.html?catid=13&art...
# Name: 43, dtype: object
# 44
# date                                             2021-01-09 00:00:00
# sentiment                                                     -0.388
# text               Demolition of Tamil genocide monument, fourth ...
# source_country                                                    lk
# queried_country                                        United States
# url                https://www.tamilnet.com/art.html?catid=13&art...
# Name: 44, dtype: object
# 45
# date                                             2021-01-16 00:00:00
# sentiment                                                     -0.114
# text               Tamil national parties demand UN to inquire in...
# source_country                                                    lk
# queried_country                                        United States
# url                https://www.tamilnet.com/art.html?catid=13&art...
# Name: 45, dtype: object
# 46
# date                                             2021-01-17 21:26:43
# sentiment                                                     -0.078
# text               WASHINGTON (RBB NEWS) – President-elect Joe Bi...
# source_country                                                    so
# queried_country                                        United States
# url                http://radiobanadir.com/biden-to-rescind-ban-o...
# Name: 46, dtype: object
# 47
# date                                             2021-01-18 00:00:00
# sentiment                                                     -0.246
# text               Tamil activists resisted three sources of outs...
# source_country                                                    lk
# queried_country                                        United States
# url                https://www.tamilnet.com/art.html?catid=79&art...
# Name: 47, dtype: object
# 48
# date                                             2021-02-15 00:00:00
# sentiment                                                      0.985
# text               The Arts Council has expressed its deep regret...
# source_country                                                    ie
# queried_country                                               Russia
# url                https://www.artscouncil.ie/News/Arts-Council-e...
# Name: 48, dtype: object
# 49
# date                                             2021-02-19 00:00:00
# sentiment                                                     -0.137
# text               UK not prepared to push for ICC option in new ...
# source_country                                                    lk
# queried_country                                                China
# url                https://www.tamilnet.com/art.html?catid=79&art...
# Name: 49, dtype: object
# 50
# date                                             2021-02-19 17:00:00
# sentiment                                                      0.062
# text               Chinese Banking and Insurance Supervisory Comm...
# source_country                                                    cn
# queried_country                                                China
# url                https://chinacopyrightandmedia.wordpress.com/2...
# Name: 50, dtype: object
# 51
# date                                             2021-02-26 00:00:00
# sentiment                                                     -0.354
# text               Tamils witness false dilemma in Geneva as geop...
# source_country                                                    lk
# queried_country                                                China
# url                https://www.tamilnet.com/art.html?catid=79&art...
# Name: 51, dtype: object
# 52
# date                                             2021-03-08 09:59:21
# sentiment                                                       0.38
# text               By The South China Sea Chronicle Initiative | ...
# source_country                                                    cn
# queried_country                                                China
# url                https://seasresearch.wordpress.com/2021/03/08/...
# Name: 52, dtype: object
# 53
# date                                             2021-03-09 00:00:00
# sentiment                                                     -0.234
# text               UK repeatedly wronged Tamils says hunger-strik...
# source_country                                                    lk
# queried_country                                                China
# url                https://www.tamilnet.com/art.html?catid=13&art...
# Name: 53, dtype: object
# 54
# date                                             2021-03-15 00:00:00
# sentiment                                                     -0.498
# text               Deceived Tamil activists in UK falsely claimed...
# source_country                                                    lk
# queried_country                                                China
# url                https://www.tamilnet.com/art.html?catid=13&art...
# Name: 54, dtype: object
# 55
# date                                             2021-03-16 01:31:02
# sentiment                                                     -0.033
# text               The Chinese National Congress passed new law t...
# source_country                                                    au
# queried_country                                                China
# url                https://australians.news/2021/03/china-makes-p...
# Name: 55, dtype: object
# 56
# date                                             2021-03-19 13:07:50
# sentiment                                                      0.025
# text               At the handing-over ceremony for the site in t...
# source_country                                                    us
# queried_country                                                China
# url                https://www.theguardian.com/uk-news/2021/mar/1...
# Name: 56, dtype: object
# 57
# date                                             2021-04-23 00:00:00
# sentiment                                                      0.159
# text               On April 16, Hong Kong’s High Court sentenced ...
# source_country                                                    CN
# queried_country                                        United States
# url                https://www.chinafile.com/reporting-opinion/vi...
# Name: 57, dtype: object
# 58
# date                                             2021-04-27 00:00:00
# sentiment                                                      0.338
# text               Last month, the U.S. government tightened its ...
# source_country                                                    CN
# queried_country                                        United States
# url                https://www.chinafile.com/reporting-opinion/vi...
# Name: 58, dtype: object
# 59
# date                                             2021-04-27 22:07:52
# sentiment                                                      0.306
# text               Joseph R. Biden Jr is the most experienced per...
# source_country                                                    au
# queried_country                                        United States
# url                https://theconversation.com/bidens-first-100-d...
# Name: 59, dtype: object
# 60
# date                                             2021-04-28 23:59:38
# sentiment                                                     -0.912
# text               Some depositors allege wrong doing by Bank of ...
# source_country                                                    fm
# queried_country                                        United States
# url                http://www.kpress.info/index.php?option=com_co...
# Name: 60, dtype: object
# 61
# date                                             2021-04-29 00:00:44
# sentiment                                                     -0.132
# text               May 13th planned for repatriation of stranded ...
# source_country                                                    fm
# queried_country                                        United States
# url                http://www.kpress.info/index.php?option=com_co...
# Name: 61, dtype: object
# 62
# date                                             2021-05-10 20:10:42
# sentiment                                                      0.121
# text               Dr. Hilda Heine, former President of the Marsh...
# source_country                                                    us
# queried_country                                        United States
# url                https://pidp.eastwestcenter.org/2021/05/10/for...
# Name: 62, dtype: object
# 63
# date                                             2021-05-13 00:00:00
# sentiment                                                      0.354
# text               The Arts Council has expressed its sadness at ...
# source_country                                                    ie
# queried_country                                        United States
# url                https://www.artscouncil.ie/News/Arts-Council-r...
# Name: 63, dtype: object
# 64
# date                                             2021-05-14 00:00:00
# sentiment                                                      0.036
# text               On July 1, the Chinese Communist Party will co...
# source_country                                                    CN
# queried_country                                        United States
# url                https://www.chinafile.com/reporting-opinion/vi...
# Name: 64, dtype: object
# 65
# date                                             2021-05-17 09:00:00
# sentiment                                                      0.393
# text               MADISON, Wis. – One Wisconsin Army National Gu...
# source_country                                                    us
# queried_country                                        United States
# url                https://www.army.mil/article/246428/wisconsin_...
# Name: 65, dtype: object
# 66
# date                                             2021-05-17 20:15:59
# sentiment                                                     -0.073
# text               As Israel and Hamas have pressed closer to all...
# source_country                                                    us
# queried_country                                        United States
# url                https://www.theguardian.com/world/2021/may/17/...
# Name: 66, dtype: object
# 67
# date                                             2021-06-01 00:00:00
# sentiment                                                      0.392
# text               While U.S.-China and U.S.-Russia relations hav...
# source_country                                                    CN
# queried_country                                               Russia
# url                https://www.chinafile.com/library/china-world-...
# Name: 67, dtype: object
# 68
# date                                             2021-06-11 08:09:32
# sentiment                                                       -1.0
# text               When Dmitry Argarkov was sent a letter offerin...
# source_country                                                    au
# queried_country                                               Russia
# url                https://ozzienews.com/financial/man-who-create...
# Name: 68, dtype: object
# 69
# date                                             2021-06-21 00:00:00
# sentiment                                                     -0.321
# text               In April, ChinaFile sent a short questionnaire...
# source_country                                                    CN
# queried_country                                                China
# url                https://www.chinafile.com/conversation/will-i-...
# Name: 69, dtype: object
# 70
# date                                             2021-06-22 00:29:42
# sentiment                                                     -0.036
# text               The UN rights chief has called for concerted a...
# source_country                                                    us
# queried_country                                                China
# url                https://www.theguardian.com/world/2021/jun/21/...
# Name: 70, dtype: object
# 71
# date                                             2021-06-24 00:00:00
# sentiment                                                      0.135
# text               Over the past few years, Europe and the United...
# source_country                                                    CN
# queried_country                                                China
# url                https://www.chinafile.com/library/china-world-...
# Name: 71, dtype: object
# 72
# date                                             2021-06-24 08:08:16
# sentiment                                                     -0.106
# text               Thirteen genetic sequences — isolated from peo...
# source_country                                                    us
# queried_country                                                China
# url                https://www.buzzfeednews.com/article/peteraldh...
# Name: 72, dtype: object
# 73
# date                                             2021-06-30 06:47:56
# sentiment                                                     -0.124
# text               Local buses, recycling bins and leafletting we...
# source_country                                                    mx
# queried_country                                                China
# url                https://www.amnesty.org/en/latest/news/2021/06...
# Name: 73, dtype: object
# 74
# date                                             2021-06-30 08:00:32
# sentiment                                                     -0.167
# text               It is hard to believe it’s happening again, ev...
# source_country                                                    us
# queried_country                                                China
# url                https://www.theguardian.com/commentisfree/2021...
# Name: 74, dtype: object
# 75
# date                                             2021-07-01 19:24:30
# sentiment                                                       -0.3
# text               Your otherwise excellent editorial on the cent...
# source_country                                                    us
# queried_country                                                China
# url                https://www.theguardian.com/world/2021/jul/01/...
# Name: 75, dtype: object
# 76
# date                                             2021-07-03 02:14:28
# sentiment                                                     -0.171
# text               Top UN officials have warned the Security Coun...
# source_country                                                    us
# queried_country                                                China
# url                https://www.theguardian.com/world/2021/jul/03/...
# Name: 76, dtype: object
# 77
# date                                             2021-07-06 15:00:04
# sentiment                                                     -0.377
# text               Four Tibetan monks were sentenced to up to 20 ...
# source_country                                                    us
# queried_country                                                China
# url                https://www.theguardian.com/world/2021/jul/06/...
# Name: 77, dtype: object
# 78
# date                                             2021-07-10 00:00:00
# sentiment                                                     -0.064
# text               Just days after its lucrative listing on the N...
# source_country                                                    CN
# queried_country                                                China
# url                https://www.chinafile.com/reporting-opinion/vi...
# Name: 78, dtype: object
# 79
# date                                             2021-08-11 07:01:39
# sentiment                                                     -0.211
# text               Ethiopian government forces have been systemat...
# source_country                                                    us
# queried_country                                              Belgium
# url                https://www.theguardian.com/global-development...
# Name: 79, dtype: object
# 80
# date                                             2021-08-19 00:00:00
# sentiment                                                      0.022
# text               The short story that follows was written 20 ye...
# source_country                                                    CN
# queried_country                                        United States
# url                https://www.chinafile.com/reporting-opinion/fe...
# Name: 80, dtype: object
# 81
# date                                             2021-08-19 15:12:03
# sentiment                                                      -0.22
# text               In March last year, it was predicted that the ...
# source_country                                                    us
# queried_country                                        United States
# url                https://www.theguardian.com/global-development...
# Name: 81, dtype: object
# 82
# date                                             2021-08-24 12:00:47
# sentiment                                                     -0.131
# text               The mobile phones of nine Bahraini activists, ...
# source_country                                                    us
# queried_country                                        United States
# url                https://www.theguardian.com/world/2021/aug/24/...
# Name: 82, dtype: object
# 83
# date                                             2021-08-26 08:19:44
# sentiment                                                      0.078
# text               MOSCOW: Russian President Vladimir Putin and h...
# source_country                                                    in
# queried_country                                        United States
# url                https://transasianews.com/open-article/2021/ce...
# Name: 83, dtype: object
# 84
# date                                             2021-08-27 06:00:07
# sentiment                                                     -0.017
# text               A war of words has erupted on Cyprus as the di...
# source_country                                                    us
# queried_country                                        United States
# url                https://www.theguardian.com/world/2021/aug/27/...
# Name: 84, dtype: object
# 85
# date                                             2021-09-02 00:00:00
# sentiment                                                     -0.029
# text               Over the past year, government and non-governm...
# source_country                                                    CN
# queried_country                                        United States
# url                https://www.chinafile.com/reporting-opinion/vi...
# Name: 85, dtype: object
# 86
# date                                             2021-09-09 22:13:20
# sentiment                                                     -0.152
# text               The 20th anniversary of the September 11 terro...
# source_country                                                    au
# queried_country                                        United States
# url                https://theconversation.com/20-years-after-9-1...
# Name: 86, dtype: object
# 87
# date                                             2021-09-11 21:54:33
# sentiment                                                      0.466
# text               The Global Bhutanese Campaign Coordination Com...
# source_country                                                    us
# queried_country                                        United States
# url                https://www.bhutannewsservice.org/diaspora-cam...
# Name: 87, dtype: object
# 88
# date                                             2021-09-14 03:32:12
# sentiment                                                     -0.405
# text               A raging house fire has killed five resettled ...
# source_country                                                    us
# queried_country                                        United States
# url                https://www.bhutannewsservice.org/a-raging-hou...
# Name: 88, dtype: object
# 89
# date                                             2021-09-16 02:04:20
# sentiment                                                      0.179
# text               Australia will build a fleet of nuclear submar...
# source_country                                                    au
# queried_country                                        United States
# url                https://theconversation.com/australia-to-build...
# Name: 89, dtype: object
# 90
# date                                             2021-09-19 07:00:00
# sentiment                                                      0.347
# text               HANOI, VIETNAM — Vietnam’s longstanding rivalr...
# source_country                                                    us
# queried_country                                               Russia
# url                https://www.voanews.com/a/vietnamese-president...
# Name: 90, dtype: object
# 91
# date                                             2021-09-23 00:00:00
# sentiment                                                      0.116
# text               In 1980, writing the last paragraph of the las...
# source_country                                                    CN
# queried_country                                               Russia
# url                https://www.chinafile.com/reporting-opinion/vi...
# Name: 91, dtype: object
# 92
# date                                             2021-10-05 09:00:00
# sentiment                                                      0.037
# text               Russia and Pakistan have urged Tajikistan and ...
# source_country                                                    us
# queried_country                                               Russia
# url                https://thediplomat.com/2021/10/tensions-rise-...
# Name: 92, dtype: object
# 93
# date                                             2021-10-11 19:09:22
# sentiment                                                     -0.177
# text               Rickert told the DOJ he also had a video of La...
# source_country                                                    us
# queried_country                                               Russia
# url                https://www.buzzfeednews.com/article/christoph...
# Name: 93, dtype: object
# 94
# date                                             2021-10-13 21:13:05
# sentiment                                                      0.162
# text               Part 1 By Dr Ivelaw Lloyd Griffith Northern So...
# source_country                                                    gy
# queried_country                                               Russia
# url                https://www.stabroeknews.com/2021/10/13/guyana...
# Name: 94, dtype: object
# 95
# date                                             2021-10-17 16:00:29
# sentiment                                                     -0.443
# text               Flicking through the news one day in early 201...
# source_country                                                    us
# queried_country                                                China
# url                https://www.theguardian.com/global-development...
# Name: 95, dtype: object
# 96
# date                                             2021-10-19 09:00:00
# sentiment                                                      0.376
# text               Destinations Food and Drink Stay News Videos S...
# source_country                                                    us
# queried_country                                                China
# url                https://edition.cnn.com/videos/travel/2021/10/...
# Name: 96, dtype: object
# 97
# date                                             2021-10-19 20:29:25
# sentiment                                                      0.168
# text               Search Advanced Search… Home News Cambodia Chi...
# source_country                                                    us
# queried_country                                                China
# url                   https://www.rfa.org/english/benarlogo.png/view
# Name: 97, dtype: object
# 98
# date                                             2021-10-20 00:00:00
# sentiment                                                     -0.235
# text               In what many observers have termed a “regulato...
# source_country                                                    CN
# queried_country                                                China
# url                https://www.chinafile.com/conversation/china-r...
# Name: 98, dtype: object
# 99
# date                                             2021-10-21 00:00:00
# sentiment                                                      0.095
# text               Roughly two thousand years ago, the arrival in...
# source_country                                                    CN
# queried_country                                                China
# url                https://www.chinafile.com/library/nyrb-china-a...
# Name: 99, dtype: object
# 100
# date                                             2021-10-21 18:15:27
# sentiment                                                     -0.037
# text               Highlights and livestreams of Boston Celtics g...
# source_country                                                    us
# queried_country                                                China
# url                https://www.theguardian.com/sport/2021/oct/21/...
# Name: 100, dtype: object
# 101
# date                                             2021-10-23 02:19:06
# sentiment                                                     -0.155
# text               WASHINGTON, Oct 22 (Reuters) - The White House...
# source_country
# queried_country                                                China
# url                https://www.reuters.com/world/china/white-hous...
# Name: 101, dtype: object
# 102
# date                                             2021-10-23 02:53:12
# sentiment                                                     -0.472
# text               [1/3]Traders work on the floor of the New York...
# source_country
# queried_country                                                China
# url                https://www.reuters.com/business/global-market...
# Name: 102, dtype: object
# 103
# date                                             2021-10-26 07:00:08
# sentiment                                                     -0.087
# text               It was a pleasant, breezy day in late Septembe...
# source_country                                                    us
# queried_country                                                China
# url                https://www.theguardian.com/news/2021/oct/26/w...
# Name: 103, dtype: object
# 104
# date                                             2021-10-26 09:00:00
# sentiment                                                      0.184
# text               Now is the time to support independent reporti...
# source_country                                                    us
# queried_country                                                China
# url                https://www.themoscowtimes.com/2021/10/26/why-...
# Name: 104, dtype: object
# 105
# date                                             2021-11-26 14:59:22
# sentiment                                                     -0.516
# text               The Government of Antigua and Barbuda has upda...
# source_country                                                    GB
# queried_country                                              Belgium
# url                https://antigua-barbuda.com/antigua-barbuda-tr...
# Name: 105, dtype: object
# 106
# date                                             2021-11-30 00:00:00
# sentiment                                                      0.253
# text               The following is a list of foreign NGOs which ...
# source_country                                                    CN
# queried_country                                              Belgium
# url                https://www.chinafile.com/ngo/latest/list-of-d...
# Name: 106, dtype: object
# 107
# date                                             2021-12-10 12:08:50
# sentiment                                                     -0.352
# text               The Government of Antigua and Barbuda updated ...
# source_country                                                    GB
# queried_country                                              Belgium
# url                https://antigua-barbuda.com/antigua-barbuda-tr...
# Name: 107, dtype: object
# 108
# date                                             2021-12-16 15:42:00
# sentiment                                                      0.575
# text               In 1985, the small farming town of Muscatine i...
# source_country                                                    us
# queried_country                                        United States
# ...
# Name: 359, dtype: object
# 360
# date                                             2024-01-04 13:58:56
# sentiment                                                      0.104
# text               We asked some of our most perceptive journalis...
# source_country                                                    us
# queried_country                                               Russia
# url                https://www.rferl.org/a/russia-purchasing-iran...
# Name: 360, dtype: object
# 361
# date                                             2024-01-04 17:49:46
# sentiment                                                      0.104
# text               We asked some of our most perceptive journalis...
# source_country                                                    us
# queried_country                                               Russia
# url                https://www.rferl.org/a/iran-kerman-soleimani-...
# Name: 361, dtype: object
# 362
# date                                             2024-01-05 13:59:11
# sentiment                                                      0.104
# text               We asked some of our most perceptive journalis...
# source_country                                                    us
# queried_country                                               Russia
# url                https://www.rferl.org/a/iran-head-scarf-two-ye...
# Name: 362, dtype: object
# 363
# date                                             2024-01-05 16:25:08
# sentiment                                                      0.104
# text               We asked some of our most perceptive journalis...
# source_country                                                    us
# queried_country                                               Russia
# url                https://www.rferl.org/a/iran-soleimani-bombing...
# Name: 363, dtype: object
# 364
# date                                             2024-01-05 19:49:57
# sentiment                                                      0.104
# text               We asked some of our most perceptive journalis...
# source_country                                                    us
# queried_country                                               Russia
# url                https://www.rferl.org/a/iran-shuts-borders-pak...
# Name: 364, dtype: object
# 365
# date                                             2024-01-06 10:50:19
# sentiment                                                      0.104
# text               We asked some of our most perceptive journalis...
# source_country                                                    us
# queried_country                                               Russia
# url                https://www.rferl.org/a/iran-revolutionary-gua...
# Name: 365, dtype: object
# 366
# date                                             2024-03-01 17:51:00
# sentiment                                                      0.225
# text               Menu Menu World U.S. Election 2024 Politics Sp...
# source_country                                                    us
# queried_country                                                China
# url                https://apnews.com/article/china-us-foreign-in...
# Name: 366, dtype: object
# 367
# date                                             2024-02-04 21:54:40
# sentiment                                                      0.856
# text               Last Updated on 2024/02/04 The Genesis of Chin...
# source_country                                                    cn
# queried_country                                                China
# url                https://china-underground.com/2024/02/04/prehi...
# Name: 367, dtype: object
# 368
# date                                             2024-02-26 22:19:59
# sentiment                                                      0.057
# text               This book is different from your other researc...
# source_country                                                    us
# queried_country                                                China
# url                https://uscnpm.org/2024/02/22/interview-with-d...
# Name: 368, dtype: object
# 369
# date                                             2024-02-15 03:18:35
# sentiment                                                      0.111
# text               The Chinese government spoke out this week aga...
# source_country                                                    us
# queried_country                                                China
# url                https://chinadigitaltimes.net/2024/02/china-cr...
# Name: 369, dtype: object
# 370
# date                                             2024-03-04 08:19:00
# sentiment                                                     -0.136
# text               The explosive growth of cross-border e-commerc...
# source_country                                                    us
# queried_country                                                China
# url                https://apnews.com/article/china-trade-de-mini...
# Name: 370, dtype: object
# 371
# date                                             2024-02-05 07:26:41
# sentiment                                                      0.222
# text               YAN YUQING Recently, I’ve seen some of the cha...
# source_country                                                    ng
# queried_country                                                China
# url                https://independent.ng/taiwans-elections-nothi...
# Name: 371, dtype: object
# 372
# date                                             2024-02-23 14:49:00
# sentiment                                                       0.27
# text               China’s activities in the security and defense...
# source_country                                                    us
# queried_country                                                China
# url                https://thediplomat.com/2024/02/chinas-securit...
# Name: 372, dtype: object
# 373
# date                                             2024-02-26 21:38:59
# sentiment                                                      0.271
# text               The discourse surrounding China's influence in...
# source_country                                                    us
# queried_country                                                China
# url                https://thediplomat.com/2024/02/chinas-influen...
# Name: 373, dtype: object
# 374
# date                                             2024-02-05 07:00:19
# sentiment                                                      0.428
# text               Global Impact is a weekly curated newsletter f...
# source_country                                                    cn
# queried_country                                                China
# url                https://www.scmp.com/economy/global-economy/ar...
# Name: 374, dtype: object
# 375
# date                                             2024-02-20 04:38:00
# sentiment                                                       0.44
# text               Welcome to the winners of Asia's Best Deals fo...
# source_country                                                    hk
# queried_country                                                China
# url                https://www.financeasia.com/article/financeasi...
# Name: 375, dtype: object
# 376
# date                                             2024-03-26 06:24:03
# sentiment                                                      0.019
# text               England and Belgium lock horns at Wembley on T...
# source_country                                                    gb
# queried_country                                              Belgium
# url                https://www.mirror.co.uk/betting/football/engl...
# Name: 376, dtype: object
# 377
# date                                             2024-03-23 17:00:32
# sentiment                                                      0.514
# text               Saturday, 23 March 2024 ePaper Puzzles Our Jou...
# source_country                                                    ie
# queried_country                                              Belgium
# url                https://www.independent.ie/sport/soccer/intern...
# Name: 377, dtype: object
# 378
# date                                             2024-03-26 08:34:39
# sentiment                                                      0.199
# text               Following a late defeat against Brazil at the ...
# source_country                                                    gb
# queried_country                                              Belgium
# url                https://www.independent.co.uk/sport/football/e...
# Name: 378, dtype: object
# 379
# date                                             2024-03-23 20:50:03
# sentiment                                                     -0.123
# text               Republic of Ireland 0 Belgium 0 AN INTERREGNUM...
# source_country                                                    ie
# queried_country                                              Belgium
# url                https://www.the42.ie/ireland-belgium-6-6335809...
# Name: 379, dtype: object
# 380
# date                                             2024-03-26 07:00:00
# sentiment                                                      0.326
# text               England are back in action again tonight (Pict...
# source_country                                                    gb
# queried_country                                              Belgium
# url                https://metro.co.uk/2024/03/26/england-vs-belg...
# Name: 380, dtype: object
# 381
# date                                             2024-03-14 07:30:00
# sentiment                                                      0.288
# text               England are back in action later this month (P...
# source_country                                                    gb
# queried_country                                              Belgium
# url                https://metro.co.uk/2024/03/14/england-vs-belg...
# Name: 381, dtype: object
# 382
# date                                             2024-03-18 11:06:02
# sentiment                                                      0.462
# text               Princess Elisabeth of Belgium has taken time o...
# source_country                                                    gb
# queried_country                                              Belgium
# url                https://www.dailymail.co.uk/femail/article-132...
# Name: 382, dtype: object
# 383
# date                                             2024-03-26 23:22:49
# sentiment                                                     -0.334
# text               JUDE BELLINGHAM STRUCK at the death to salvage...
# source_country                                                    ie
# queried_country                                              Belgium
# url                https://www.the42.ie/england-v-belgium-6338288...
# Name: 383, dtype: object
# 384
# date                                             2024-03-27 13:38:04
# sentiment                                                      0.077
# text               As international breaks go, it was hardly a cl...
# source_country                                                    gb
# queried_country                                              Belgium
# url                https://www.mirror.co.uk/sport/football/news/e...
# Name: 384, dtype: object
# 385
# date                                             2024-03-27 14:15:31
# sentiment                                                      0.038
# text               On the plane Jordan Pickford’s error against B...
# source_country                                                    us
# queried_country                                              Belgium
# url                https://www.theguardian.com/football/2024/mar/...
# Name: 385, dtype: object
# 386
# date                                             2024-04-03 12:00:00
# sentiment                                                      0.185
# text               A federal court is picking an unusual fight wi...
# source_country                                                    us
# queried_country                                        United States
# url                https://www.vox.com/scotus/24117949/supreme-co...
# Name: 386, dtype: object
# 387
# date                                             2024-04-03 12:00:00
# sentiment                                                      0.095
# text               Sign up for The Brief, The Texas Tribune’s dai...
# source_country                                                    us
# queried_country                                        United States
# url                https://www.texastribune.org/2024/04/03/club-f...
# Name: 387, dtype: object
# 388
# date                                             2024-04-03 12:00:02
# sentiment                                                     -0.135
# text               California has been revealed as a lead U.S. em...
# source_country                                                    us
# queried_country                                        United States
# url                https://www.newsweek.com/california-revleaed-w...
# Name: 388, dtype: object
# 389
# date                                             2024-04-03 12:00:47
# sentiment                                                      0.139
# text               U.S. Secretary of State Antony Blinken has sai...
# source_country                                                    lb
# queried_country                                        United States
# url                https://www.naharnet.com/stories/en/304351-bli...
# Name: 389, dtype: object
# 390
# date                                             2024-04-03 12:01:41
# sentiment                                                     -0.115
# text               Critics are raging against New York’s proposed...
# source_country                                                    us
# queried_country                                        United States
# url                https://nypost.com/2024/04/03/us-news/ny-propo...
# Name: 390, dtype: object
# 391
# date                                             2024-04-03 12:02:25
# sentiment                                                      0.545
# text               Wednesday, 3 April 2024 ePaper Puzzles Our Jou...
# source_country                                                    ie
# queried_country                                        United States
# url                https://www.independent.ie/videos/irish-news/e...
# Name: 391, dtype: object
# 392
# date                                             2024-04-03 12:03:51
# sentiment                                                      0.264
# text               Automotive After-Sales Service Market Automoti...
# source_country                                                    in
# queried_country                                        United States
# url                https://www.headlinesoftoday.com/topic/press-r...
# Name: 392, dtype: object
# 393
# date                                             2024-04-03 12:05:51
# sentiment                                                      0.161
# text               Ma*****od' To 'F**k': CBFC Removes Cuss Words ...
# source_country                                                    in
# queried_country                                        United States
# url                https://www.freepressjournal.in/entertainment/...
# Name: 393, dtype: object
# 394
# date                                             2024-04-03 12:05:56
# sentiment                                                      0.123
# text               Last December the government of the Indian sta...
# source_country                                                    fr
# queried_country                                        United States
# url                           https://mondediplo.com/2024/04/05india
# Name: 394, dtype: object
# 395
# date                                             2024-04-03 12:05:58
# sentiment                                                      0.075
# text               Prince Harry is said to be deeply concerned ab...
# source_country                                                    gb
# queried_country                                        United States
# url                https://www.mirror.co.uk/3am/us-celebrity-news...
# Name: 395, dtype: object

# %% [markdown]
# The below DataFrame contains the information that we ended up continuing with. It is saved as a CSV locally.

# %%
test.head()
# Out:
#                   date  sentiment  \
# 0  2019-06-12 18:48:59     -0.308
# 1  2019-07-12 17:14:00     -0.108
# 2  2019-10-23 15:32:04      0.292
# 3  2019-10-23 15:34:13      0.398
# 4  2019-10-23 15:37:39      0.146
#
#                                                 text source_country  \
# 0  It’s time we start talking about climate chang...             mx
# 1  Even now, as more frequent "king tides" bubble...             us
# 2  The second meeting of the Board of senior memb...             uz
# 3  The Shanghai Cooperation Organization establis...             uz
# 4  All participants of the exhibition “Tea and Co...             uz
#
#   queried_country                                                url  \
# 0          Russia  https://www.amnesty.org/en/latest/news/2019/06...
# 1           China  https://edition.cnn.com/2019/07/11/us/miami-li...
# 2          Russia  http://www.uzreport.com/sco-interbank-associat...
# 3          Russia  http://www.uzreport.com/entrepreneur-committee...
# 4          Russia  http://www.uzreport.com/over-7000-people-visit...
#
#    Safety Index
# 0      0.585000
# 1      0.784286
# 2      0.585000
# 3      0.585000
# 4      0.585000
